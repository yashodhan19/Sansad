# %%
import datetime
import uuid
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("ls_2019_result.csv", sep="|")
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8568 entries, 0 to 8567
# Data columns (total 11 columns):
# AC_Code             8568 non-null int64
# Candidate           8568 non-null object
# Constituency        8568 non-null object
# EVM Votes           8568 non-null int64
# OSN                 8568 non-null int64
# Party               8568 non-null object
# Percent of Votes    8568 non-null float64
# Postal Votes        8568 non-null int64
# State               8568 non-null object
# State_Code          8568 non-null object
# Total of Votes      8568 non-null int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 736.4+ KB
# None
#    AC_Code                                          Candidate Constituency  \
# 0        1                                KISHORE CHANDRA DEO       Aruku
# 1        1  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...       Aruku
# 2        1                                   GODDETI. MADHAVI       Aruku
# 3        1                             SHRUTI DEVI VYRICHERLA       Aruku
# 4        1                                GANGULAIAH VAMPURU.       Aruku
#
#    EVM Votes  OSN                                  Party  Percent of Votes  \
# 0     336163    1                           Telugu Desam             31.46
# 1      17578    2                 Bharatiya Janata Party              1.66
# 2     557561    3  Yuvajana Sramika Rythu Congress Party             52.32
# 3      17656    4               Indian National Congress              1.65
# 4      42245    5                         Janasena Party              3.98
#
#    Postal Votes           State State_Code  Total of Votes
# 0          1938  Andhra Pradesh        S01          338101
# 1           289  Andhra Pradesh        S01           17867
# 2          4629  Andhra Pradesh        S01          562190
# 3            74  Andhra Pradesh        S01           17730
# 4           549  Andhra Pradesh        S01           42794

# %%
df['AC_Code'] = df['AC_Code'].astype(str).str.zfill(2)
df['OSN'] = df['OSN'].astype(str).str.zfill(2)
df["Candidate_ID"] = df['State_Code'] + '_' + df['AC_Code'].astype(str)+ '_' + df['OSN'].astype(str)
df["Constituency_ID"] = df['State_Code'] + '_' + df['AC_Code']

# Rank the candidates by Total Votes, Within a constituency
df['AC_Rank'] = df.groupby(['State','AC_Code'])['Total of Votes'].rank(ascending=False)
df.sort_values(['State','AC_Code','AC_Rank'], inplace=True)

# Calculate Difference of votes between positions
df['Vote_Diff']= df.groupby(['State','AC_Code'])['Total of Votes'].diff(-1)

# Find Constituency Type
df['Constituency'], df['Constituency_Type'] = df['Constituency'].str.split('\(', 1).str
df['Constituency_Type'] = df['Constituency_Type'].fillna("GEN")
df['Constituency_Type'] = df['Constituency_Type'].str.replace("\)", "")
df.head()
# Out:
#      AC_Code              Candidate               Constituency  EVM Votes OSN  \
# 8302      01     KULDEEP RAI SHARMA  Andaman & Nicobar Islands      95249  02
# 8304      01           VISHAL JOLLY  Andaman & Nicobar Islands      93772  04
# 8310      01  PARITOSH KUMAR HALDAR  Andaman & Nicobar Islands       5339  10
# 8305      01         SANJAY MESHACK  Andaman & Nicobar Islands       2837  05
# 8303      01           PRAKASH MINJ  Andaman & Nicobar Islands       2478  03
#
#                          Party  Percent of Votes  Postal Votes  \
# 8302  Indian National Congress             45.98            59
# 8304    Bharatiya Janata Party             45.30           129
# 8310               Independent              2.58             2
# 8305           Aam Aadmi Party              1.37             2
# 8303       Bahujan Samaj Party              1.20             8
#
#                           State State_Code  Total of Votes Candidate_ID  \
# 8302  Andaman & Nicobar Islands        U01           95308    U01_01_02
# 8304  Andaman & Nicobar Islands        U01           93901    U01_01_04
# 8310  Andaman & Nicobar Islands        U01            5341    U01_01_10
# 8305  Andaman & Nicobar Islands        U01            2839    U01_01_05
# 8303  Andaman & Nicobar Islands        U01            2486    U01_01_03
#
#      Constituency_ID  AC_Rank  Vote_Diff Constituency_Type
# 8302          U01_01      1.0     1407.0               GEN
# 8304          U01_01      2.0    88560.0               GEN
# 8310          U01_01      3.0     2502.0               GEN
# 8305          U01_01      4.0      353.0               GEN
# 8303          U01_01      5.0      765.0               GEN

# %%
winner = df.loc[df.groupby(["State", "Constituency", "Constituency_ID"])["AC_Rank"].idxmin()]
winner.head()
# Out:
#      AC_Code                       Candidate               Constituency  \
# 8302      01              KULDEEP RAI SHARMA  Andaman & Nicobar Islands
# 307       07                 CHINTA ANURADHA                Amalapuram
# 280       05  Dr.Beesetti Venkata Satyavathi                 Anakapalli
# 152       19                 TALARI RANGAIAH                  Anantapur
# 2         01                GODDETI. MADHAVI                     Aruku
#
#       EVM Votes OSN                                  Party  Percent of Votes  \
# 8302      95249  02               Indian National Congress             45.98
# 307      481358  03  Yuvajana Sramika Rythu Congress Party             39.43
# 280      583210  03  Yuvajana Sramika Rythu Congress Party             47.33
# 152      690901  02  Yuvajana Sramika Rythu Congress Party             51.79
# 2        557561  03  Yuvajana Sramika Rythu Congress Party             52.32
#
#       Postal Votes                      State State_Code  Total of Votes  \
# 8302            59  Andaman & Nicobar Islands        U01           95308
# 307           3955             Andhra Pradesh        S01          485313
# 280           3016             Andhra Pradesh        S01          586226
# 152           4307             Andhra Pradesh        S01          695208
# 2             4629             Andhra Pradesh        S01          562190
#
#      Candidate_ID Constituency_ID  AC_Rank  Vote_Diff Constituency_Type
# 8302    U01_01_02          U01_01      1.0     1407.0               GEN
# 307     S01_07_03          S01_07      1.0    39966.0               GEN
# 280     S01_05_03          S01_05      1.0    89192.0               GEN
# 152     S01_19_02          S01_19      1.0   141428.0               GEN
# 2       S01_01_03          S01_01      1.0   224089.0               GEN
